# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt 
import csv

# %%
df=pd.read_csv("/content/Table5.csv")
df
# Out:
#                                      Cause of Death    Total     Male   Female
# 0                    Malignant neoplasm of prostate    3,038    3,038       -
# 1                                 Diabetes Mellitus   32,106   15,796   16,310
# 2     Endocrine, nutritional and metabolic diseases   42,654   20,283   22,371
# 3         Certain infectious and parasitic diseases   40,929   26,486   14,443
# 4                                         Pneumonia   56,815   27,863   28,952
# 5                                         Neoplasms   67,138   31,870   35,268
# 6                         Cerebrosvascular diseases   61,959   35,020   26,939
# 7                Diseases of the respiratory system   87,720   48,842   38,878
# 8                          Ischaemic heart diseases   88,433   53,128   35,305
# 9                Diseases of the circulatory system  201,483  115,130   86,353
# 10                                            Total  590,709  337,789  252,920

# %%
df[['Cause of Death','Male','Female']]
# Out:
#                                      Cause of Death     Male   Female
# 0                    Malignant neoplasm of prostate    3,038       -
# 1                                 Diabetes Mellitus   15,796   16,310
# 2     Endocrine, nutritional and metabolic diseases   20,283   22,371
# 3         Certain infectious and parasitic diseases   26,486   14,443
# 4                                         Pneumonia   27,863   28,952
# 5                                         Neoplasms   31,870   35,268
# 6                         Cerebrosvascular diseases   35,020   26,939
# 7                Diseases of the respiratory system   48,842   38,878
# 8                          Ischaemic heart diseases   53,128   35,305
# 9                Diseases of the circulatory system  115,130   86,353
# 10                                            Total  337,789  252,920

# %%
Death = df['Cause of Death']
Male = df['Male']
Female = df['Female']


fig = plt.figure(figsize=(50,25))
plt.bar(Death,Female)
plt.xlabel('Death')
plt.ylabel('Female')
plt.title('Death caused by Diseases (Male)')

plt.show()

# %%
Death = df['Cause of Death']
Male = df['Male']
Female = df['Female']
Total = df['Total']


fig = plt.figure(figsize=(50,25))
plt.bar(Death,Male)
plt.xlabel('Death')
plt.ylabel('Female')
plt.title('Death caused by Diseases (Female)')


plt.show()

# %%
Death = 'Cause of Death'
Male = 'Male'
sorted_df = df.sort_values(by=Death, ascending=False)
sorted_df = sorted_df.reset_index(drop=True)
plt.figure(figsize=(12, 6))  
x = sorted_df['Cause of Death'] 
y = sorted_df['Male']  
plt.bar(x,y)
plt.xlabel('Male')  
plt.ylabel('Deaths')  
plt.title('Death Caused by Disease')
plt.xticks(rotation=90)  
plt.show()
