# %% [markdown]
# <a href="https://colab.research.google.com/github/Glennarcega/IT-BA-3203-PROJECT/blob/main/Social_Factor_of_death.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt 
import csv

# %%
df= pd.read_csv("https://raw.githubusercontent.com/Glennarcega/IT-BA-3203-PROJECT/main/Summaryofdeath.csv")
df
# Out:
#     Year Number of Deaths     Male   Female  Crude Death Rate  Male.1  \
# 0   2000          366,931  217,404  149,527               4.8     5.6
# 1   2001          381,834  225,879  155,955               4.9     5.7
# 2   2002          396,297  232,530  163,767               4.9     5.8
# 3   2003          396,331  233,739  162,592               4.8     5.7
# 4   2004          403,191  237,750  165,441               4.8     5.7
# 5   2005          426,054  250,102  175,952               5.0     5.8
# 6   2006          441,036  258,300  182,736               5.1     5.9
# 7   2007          441,956  258,178  183,778               5.0     5.8
# 8   2008          461,581  268,764  192,817               5.1     5.9
# 9   2009          480,820  279,513  201,307               5.2     6.0
# 10  2010          488,265  282,381  205,884               5.2     6.0
# 11  2011          498,486  288,730  209,756               5.3     6.0
# ...

# %% [markdown]
# # **Total  of death from 2000 to 2018**

# %%
df[['Year','Number of Deaths','Male','Female']]
# Out:
#     Year Number of Deaths     Male   Female
# 0   2000          366,931  217,404  149,527
# 1   2001          381,834  225,879  155,955
# 2   2002          396,297  232,530  163,767
# 3   2003          396,331  233,739  162,592
# 4   2004          403,191  237,750  165,441
# 5   2005          426,054  250,102  175,952
# 6   2006          441,036  258,300  182,736
# 7   2007          441,956  258,178  183,778
# 8   2008          461,581  268,764  192,817
# 9   2009          480,820  279,513  201,307
# 10  2010          488,265  282,381  205,884
# 11  2011          498,486  288,730  209,756
# 12  2012          514,745  296,614  218,131
# 13  2013          531,280  304,516  226,764
# 14  2014          551,716  316,544  235,172
# 15  2015          560,605  321,624  238,981
# 16  2016          582,183  334,678  247,505
# 17  2017          579,237  332,517  246,720
# 18  2018          590,709  337,789  252,920

# %%
Year = df['Year']
Deaths = df['Number of Deaths']


fig = plt.figure(figsize=(10,5))
plt.plot(Year,InfantDeaths)
plt.xlabel('years')
plt.ylabel('Number of deaths ')
plt.title('Number of Deaths from 2000 to 2018')
plt.show()

# %% [markdown]
# # **Infant death**

# %%
df[['Year','Number of Infant Deaths','Male.2','Female.2']]
# Out:
#     Year Number of Infant Deaths  Male.2 Female.2
# 0   2000                  27,714  16,286   11,428
# 1   2001                  26,129  15,393   10,736
# 2   2002                  23,778  13,925    9,853
# 3   2003                  22,844  13,329    9,515
# 4   2004                  22,557  13,219    9,338
# 5   2005                  21,674  12,752    8,922
# 6   2006                  21,764  12,786    8,978
# 7   2007                  21,720  12,809    8,911
# 8   2008                  22,351  13,099    9,252
# 9   2009                  21,659  12,503    9,156
# 10  2010                  22,476  13,163    9,313
# 11  2011                  22,283  13,092    9,191
# 12  2012                  22,254  12,987    9,267
# 13  2013                  21,992  12,699    9,293
# 14  2014                  21,572  12,495    9,077
# 15  2015                  20,750  12,086    8,664
# 16  2016                  21,874  12,566    9,308
# 17  2017                  20,311  11,760    8,551
# ...

# %%
Year = df['Year']
InfantDeaths = df['Number of Infant Deaths']


fig = plt.figure(figsize=(10,5))
plt.bar(Year,InfantDeaths)
plt.xlabel('years')
plt.ylabel('Number of deaths ')
plt.title('Number of Infant Deaths')
plt.show()

# %% [markdown]
# # **Number of Under-Five Deaths**

# %%
df[['Year','Number of Under-Five Deaths','Male.4','Female.4']]
# Out:
#     Year Number of Under-Five Deaths  Male.4 Female.4
# 0   2000                      39,365  22,675   16,690
# 1   2001                      37,873  21,790   16,083
# 2   2002                      34,754  19,953   14,801
# 3   2003                      33,171  18,924   14,247
# 4   2004                      31,205  18,037   13,168
# 5   2005                      30,825  17,758   13,067
# 6   2006                      31,413  18,049   13,364
# 7   2007                      30,380  17,569   12,811
# 8   2008                      31,403  18,046   13,357
# 9   2009                      31,496  17,904   13,592
# 10  2010                      31,682  18,234   13,448
# 11  2011                      31,643  18,123   13,520
# 12  2012                      31,491  17,969   13,522
# 13  2013                      31,518  17,839   13,679
# 14  2014                      30,925  17,597   13,328
# 15  2015                      29,332  16,731   12,601
# ...

# %%
Year = df['Year']
UnderFiveDeaths = df['Number of Under-Five Deaths']


fig = plt.figure(figsize=(10,5))
plt.bar(Year,UnderFiveDeaths)
plt.xlabel('years')
plt.ylabel('Number of deaths ')
plt.title('Number of Under-Five Deaths')
plt.show()

# %% [markdown]
# # **Number of Child Deaths,Number of Fetal Deaths,Number of Maternal Deaths**

# %%
df[['Year','Number of Child Deaths','Number of Fetal Deaths','Number of Maternal Deaths']]
# Out:
#     Year Number of Child Deaths Number of Fetal Deaths  \
# 0   2000                 11,651                 10,360
# 1   2001                 11,744                  9,625
# 2   2002                 10,976                  9,341
# 3   2003                 10,327                  8,986
# 4   2004                  8,648                  8,935
# 5   2005                  9,151                 10,351
# 6   2006                  9,649                  8,458
# 7   2007                  8,660                  8,191
# 8   2008                  9,052                  8,306
# 9   2009                  9,837                  8,043
# 10  2010                  9,206                  8,095
# 11  2011                  9,360                  8,173
# 12  2012                  9,327                  7,862
# 13  2013                  9,526                  7,474
# 14  2014                  9,353                  7,664
# 15  2015                  8,582                  7,676
# ...

# %%
Year = df['Year']
ChildDeaths = df['Number of Child Deaths']
FetalDeath = df['Number of Fetal Deaths']

fig = plt.figure(figsize=(10,5))
plt.bar(Year,ChildDeaths)
plt.xlabel('years')
plt.ylabel('Number of deaths ')
plt.title('childeaths')
plt.show()

# %%
df= pd.read_csv("https://raw.githubusercontent.com/Glennarcega/IT-BA-3203-PROJECT/main/age%20death.csv")
df
# Out:
#       Age Group   Total    Male  Female
# 0       Under 1  21,019  12,174   8,845
# 1         1 --4   7,805   4,215   3,590
# 2          5--9   5,212   2,830   2,382
# 3        10--14   4,670   2,718   1,952
# 4         15-19   7,788   5,172   2,616
# 5         20-24  11,171   7,715   3,456
# 6         25-29  13,180   9,088   4,092
# 7         30-34  14,526   9,828   4,698
# 8         35-39  18,831  12,547   6,284
# 9         40-44  23,109  15,243   7,866
# 10        45-49  31,150  20,368  10,782
# 11        50-54  39,148  25,383  13,765
# 12        55-59  47,841  31,055  16,786
# 13        60-64  55,893  35,710  20,183
# 14        65-69  60,201  37,129  23,072
# 15        70-74  57,696  33,346  24,350
# 16        75-79  57,158  29,640  27,518
# 17        80-84  51,526  22,615  28,911
# 18        85-89  36,544  13,333  23,211
# 19        90-94  18,388   5,495  12,893
# 20  95 and over   7,708   2,070   5,638
# 21   Not Stated     145     115      30

# %%
df[['Age Group','Total']]
# Out:
#       Age Group   Total
# 0       Under 1  21,019
# 1         1 --4   7,805
# 2          5--9   5,212
# 3        10--14   4,670
# 4         15-19   7,788
# 5         20-24  11,171
# 6         25-29  13,180
# 7         30-34  14,526
# 8         35-39  18,831
# 9         40-44  23,109
# 10        45-49  31,150
# 11        50-54  39,148
# 12        55-59  47,841
# 13        60-64  55,893
# 14        65-69  60,201
# 15        70-74  57,696
# 16        75-79  57,158
# 17        80-84  51,526
# 18        85-89  36,544
# 19        90-94  18,388
# 20  95 and over   7,708
# 21   Not Stated     145

# %%
Age = df['Age Group']
ttl = df['Total']


fig = plt.figure(figsize=(14,5))
plt.bar(Age,ttl)
plt.xlabel('Age Group')
plt.ylabel('Number Of death ')

plt.show()
