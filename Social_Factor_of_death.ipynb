# %% [markdown]
# <a href="https://colab.research.google.com/github/Glennarcega/IT-BA-3203-PROJECT/blob/main/Social_Factor_of_death.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt 
import csv

# %%
df= pd.read_csv("https://raw.githubusercontent.com/Glennarcega/IT-BA-3203-PROJECT/main/Dataset/Summaryofdeath.csv")
dftbl= pd.read_csv('https://raw.githubusercontent.com/Glennarcega/IT-BA-3203-PROJECT/main/Dataset/disease.csv')
data= pd.read_csv('https://raw.githubusercontent.com/Glennarcega/IT-BA-3203-PROJECT/main/Dataset/Infant.csv')

# %% [markdown]
# # **Number of deaths from 2000 to 2018**

# %%
Year = df['Year']
Deaths = df['Number of Deaths']


plt.figure(figsize=(10,5))
plt.plot(Year,Deaths)
plt.xlabel('years')
plt.ylabel('Number of deaths ')
plt.title('Number of Deaths from 2000 to 2018')
plt.show()

# %% [markdown]
# # **Number of infant death from 2000 to 2018**

# %%
A = 'Number of Infant Deaths'
Year = 'Year'

sorted_df = df.sort_values(by=A, ascending=True)
sorted_df = sorted_df.reset_index(drop=True)
plt.figure(figsize=(12, 6))  
x = sorted_df['Year'] 
y = sorted_df['Number of Infant Deaths']  
plt.bar(x,y)
plt.xlabel('Year')  
plt.ylabel('Number of Deaths')  
plt.title('Number of Infant Death History')
plt.xticks(rotation=90)  
plt.show()

# %% [markdown]
# # **Number of under five deaths from 2000 to 2018**

# %%
B = 'Number of Under-Five Deaths'
Year = 'Year'

sorted_df = df.sort_values(by=B, ascending=True)
sorted_df = sorted_df.reset_index(drop=True)
plt.figure(figsize=(12, 6))  
x = sorted_df['Year'] 
y = sorted_df['Number of Under-Five Deaths']  
plt.bar(x,y)
plt.xlabel('Year')  
plt.ylabel('Number of Under-Five Deaths')  
plt.title('Number of Under-Five Deaths History')
plt.xticks(rotation=90)  
plt.show()

# %% [markdown]
# # **Number of Under-Five Mortality Rate from 2000 to 2018**

# %%
C = 'Under-Five Mortality Rate'
Year = 'Year'

sorted_df = df.sort_values(by=C, ascending=True)
sorted_df = sorted_df.reset_index(drop=True)
plt.figure(figsize=(12, 6))  
x = sorted_df['Year'] 
y = sorted_df['Under-Five Mortality Rate']  
plt.bar(x,y)
plt.xlabel('Year')  
plt.ylabel('Under-Five Mortality Rate')  
plt.title('Under-Five Mortality Rate History')
plt.xticks(rotation=90)  
plt.show()

# %% [markdown]
# # **Number of fetal deaths from 2000 to 2018**

# %%
D = 'Number of Fetal Deaths'
Year = 'Year'

sorted_df = df.sort_values(by=D, ascending=True)
sorted_df = sorted_df.reset_index(drop=True)
plt.figure(figsize=(12, 6))  
x = sorted_df['Year'] 
y = sorted_df['Number of Fetal Deaths']  
plt.bar(x,y)
plt.xlabel('Year')  
plt.ylabel('Number of Fetal Deaths')  
plt.title('Number of Fetal Deaths History')
plt.xticks(rotation=90)  
plt.show()

# %% [markdown]
# # **Number of maternal deaths from 2000 to 2018**

# %%
F = 'Number of Maternal Deaths'
Year = 'Year'

sorted_df = df.sort_values(by=F, ascending=True)
sorted_df = sorted_df.reset_index(drop=True)
plt.figure(figsize=(12, 6))  
x = sorted_df['Year'] 
y = sorted_df['Number of Maternal Deaths']  
plt.bar(x,y)
plt.xlabel('Year')  
plt.ylabel('Number of Maternal Deaths')  
plt.title('Number of Maternal Deaths History')
plt.xticks(rotation=90)  
plt.show()

# %% [markdown]
# # **Death Caused by Diseases (Female)**

# %%
Death = dftbl['Cause of Death']
Male = dftbl['Male']
Female = dftbl['Female']


fig = plt.figure(figsize=(50,25))
plt.bar(Death,Female)
plt.xlabel('Death')
plt.ylabel('Female')
plt.title('Death caused by Diseases (Male)')

plt.show()

# %% [markdown]
# # **Death Caused by Diseases (Male)**

# %%
Death = dftbl['Cause of Death']
Male = dftbl['Male']
Female = dftbl['Female']
Total = dftbl['Total']


fig = plt.figure(figsize=(50,25))
plt.bar(Death,Male)
plt.xlabel('Death')
plt.ylabel('Male')
plt.title('Death caused by Diseases (Female)')


plt.show()

# %% [markdown]
# # **Rate of Death Caused by Diseases**

# %%
Death = 'Cause of Death'
Male = 'Male'
sorted_dftbl = dftbl.sort_values(by=Death, ascending=False)
sorted_dftbl = sorted_dftbl.reset_index(drop=True)
plt.figure(figsize=(12, 6))  
x = sorted_dftbl['Cause of Death'] 
y = sorted_dftbl['Male']  
plt.bar(x,y)
plt.xlabel('Male')  
plt.ylabel('Deaths')  
plt.title('Death Caused by Disease')
plt.xticks(rotation=90)  
plt.show()
