# %% [markdown]
# <a href="https://colab.research.google.com/github/Glennarcega/IT-BA-3203-PROJECT/blob/main/Social_Factor_of_death.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt 
import csv

# %%
df= pd.read_csv("https://raw.githubusercontent.com/Glennarcega/IT-BA-3203-PROJECT/main/Summaryofdeath.csv")
df
# Out:
#     Year Number of Deaths     Male   Female  Crude Death Rate  Male.1  \
# 0   2000          366,931  217,404  149,527               4.8     5.6
# 1   2001          381,834  225,879  155,955               4.9     5.7
# 2   2002          396,297  232,530  163,767               4.9     5.8
# 3   2003          396,331  233,739  162,592               4.8     5.7
# 4   2004          403,191  237,750  165,441               4.8     5.7
# 5   2005          426,054  250,102  175,952               5.0     5.8
# 6   2006          441,036  258,300  182,736               5.1     5.9
# 7   2007          441,956  258,178  183,778               5.0     5.8
# 8   2008          461,581  268,764  192,817               5.1     5.9
# 9   2009          480,820  279,513  201,307               5.2     6.0
# 10  2010          488,265  282,381  205,884               5.2     6.0
# 11  2011          498,486  288,730  209,756               5.3     6.0
# ...

# %%
Year = df['Year']
Deaths = df['Number of Deaths']


plt.figure(figsize=(10,5))
plt.plot(Year,Deaths)
plt.xlabel('years')
plt.ylabel('Number of deaths ')
plt.title('Number of Deaths from 2000 to 2018')
plt.show()

# %%
E = 'Number of Deaths'
Year = 'Year'

sorted_df = df.sort_values(by=E, ascending=True)
sorted_df = sorted_df.reset_index(drop=True)
plt.figure(figsize=(12, 6))  
x = sorted_df['Year'] 
y = sorted_df['Number of Deaths']  
plt.bar(x,y)
plt.xlabel('Year')  
plt.ylabel('Number of Deaths')  
plt.title('Number of Death History')
plt.xticks(rotation=90)  
plt.show()

# %%
A = 'Number of Infant Deaths'
Year = 'Year'

sorted_df = df.sort_values(by=A, ascending=True)
sorted_df = sorted_df.reset_index(drop=True)
plt.figure(figsize=(12, 6))  
x = sorted_df['Year'] 
y = sorted_df['Number of Infant Deaths']  
plt.bar(x,y)
plt.xlabel('Year')  
plt.ylabel('Number of Deaths')  
plt.title('Number of Infant Death History')
plt.xticks(rotation=90)  
plt.show()

# %%
B = 'Number of Under-Five Deaths'
Year = 'Year'

sorted_df = df.sort_values(by=B, ascending=True)
sorted_df = sorted_df.reset_index(drop=True)
plt.figure(figsize=(12, 6))  
x = sorted_df['Year'] 
y = sorted_df['Number of Under-Five Deaths']  
plt.bar(x,y)
plt.xlabel('Year')  
plt.ylabel('Number of Under-Five Deaths')  
plt.title('Number of Under-Five Deaths History')
plt.xticks(rotation=90)  
plt.show()

# %%
C = 'Under-Five Mortality Rate'
Year = 'Year'

sorted_df = df.sort_values(by=C, ascending=True)
sorted_df = sorted_df.reset_index(drop=True)
plt.figure(figsize=(12, 6))  
x = sorted_df['Year'] 
y = sorted_df['Under-Five Mortality Rate']  
plt.bar(x,y)
plt.xlabel('Year')  
plt.ylabel('Under-Five Mortality Rate')  
plt.title('Under-Five Mortality Rate History')
plt.xticks(rotation=90)  
plt.show()

# %%
D = 'Number of Fetal Deaths'
Year = 'Year'

sorted_df = df.sort_values(by=D, ascending=True)
sorted_df = sorted_df.reset_index(drop=True)
plt.figure(figsize=(12, 6))  
x = sorted_df['Year'] 
y = sorted_df['Number of Fetal Deaths']  
plt.bar(x,y)
plt.xlabel('Year')  
plt.ylabel('Number of Fetal Deaths')  
plt.title('Number of Fetal Deaths History')
plt.xticks(rotation=90)  
plt.show()

# %%
F = 'Number of Maternal Deaths'
Year = 'Year'

sorted_df = df.sort_values(by=F, ascending=True)
sorted_df = sorted_df.reset_index(drop=True)
plt.figure(figsize=(12, 6))  
x = sorted_df['Year'] 
y = sorted_df['Number of Maternal Deaths']  
plt.bar(x,y)
plt.xlabel('Year')  
plt.ylabel('Number of Maternal Deaths')  
plt.title('Number of Maternal Deaths History')
plt.xticks(rotation=90)  
plt.show()
